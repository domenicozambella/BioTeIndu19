# %%
using DataFrames
using CSV
# Out:
# ┌ Info: Precompiling CSV [336ed68f-0bac-5ca0-87d4-7b16caf5d00b]
# └ @ Base loading.jl:1186
# ┌ Warning: Module CategoricalArrays with build ID 30501815515613 is missing from the cache.
# │ This may mean CategoricalArrays [324d7699-5711-5eae-9e2f-1d82baa6b597] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947

# %%
df = CSV.read("../dati/Cork_Airport.csv", header=25)
# Out:
# 20850×25 DataFrame. Omitted printing of 19 columns
# │ Row   │ date        │ ind    │ maxtp    │ ind_1  │ mintp    │ igmin   │
# │       │ String⍰     │ Int64⍰ │ Float64⍰ │ Int64⍰ │ Float64⍰ │ Int64⍰  │
# ├───────┼─────────────┼────────┼──────────┼────────┼──────────┼─────────┤
# │ 1     │ 01-jan-1962 │ 0      │ 2.8      │ 1      │ -2.5     │ missing │
# │ 2     │ 02-jan-1962 │ 0      │ 2.8      │ 1      │ -3.7     │ missing │
# │ 3     │ 03-jan-1962 │ 0      │ 2.3      │ 1      │ -3.8     │ missing │
# │ 4     │ 04-jan-1962 │ 0      │ 6.6      │ 0      │ 0.6      │ missing │
# │ 5     │ 05-jan-1962 │ 0      │ 9.3      │ 0      │ 0.6      │ missing │
# │ 6     │ 06-jan-1962 │ 0      │ 10.3     │ 0      │ 8.7      │ missing │
# │ 7     │ 07-jan-1962 │ 0      │ 9.6      │ 0      │ 4.4      │ missing │
# │ 8     │ 08-jan-1962 │ 0      │ 9.0      │ 0      │ 1.2      │ missing │
# │ 9     │ 09-jan-1962 │ 0      │ 6.6      │ 0      │ 2.2      │ missing │
# ...

# %%
?CSV.read
# Out:
#   CSV.read(fullpath::Union{AbstractString,IO}, sink=DataFrame; kwargs...) =>
#   typeof(sink)
#
#   Parses a delimited file into a Julia structure (a DataFrame by default, but
#   any valid Tables.jl sink function can be provided).
#
#   Minimal error-reporting happens w/ CSV.read for performance reasons; for
#   problematic csv files, try CSV.validate which takes exact same arguments as
#   CSV.read and provides much more information for why reading the file failed.
#
#   Positional arguments:
#
#     •    fullpath: can be a file name (String) of the location of the csv
#         file or IO object to read the csv from directly
#
#     •    sink: DataFrame by default, but may also be any other Tables.jl
#         sink function
#
#   Supported keyword arguments include:
#
#     •    File layout options:
#
#           •    header=1: the header argument can be an Int, indicating
#               the row to parse for column names; or a Range,
# ...
